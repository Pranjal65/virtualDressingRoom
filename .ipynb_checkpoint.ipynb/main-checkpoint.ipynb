MB 2.7 MB/s eta 0:00:07
#    --------------------- ------------------ 20.8/38.8 MB 2.7 MB/s eta 0:00:07
#    --------------------- ------------------ 21.0/38.8 MB 2.7 MB/s eta 0:00:07
#    --------------------- ------------------ 21.2/38.8 MB 2.8 MB/s eta 0:00:07
#    --------------------- ------------------ 21.3/38.8 MB 2.8 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.5/38.8 MB 2.8 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.6/38.8 MB 627.2 kB/s eta 0:00:28
# ERROR: THESE PACKAGES DO NOT MATCH THE HASHES FROM THE REQUIREMENTS FILE. If you have updated the package versions, please update the hashes. Otherwise, examine the package contents carefully; someone may have tampered with them.
#     unknown package:
#         Expected sha256 32dbbd94c26f611dc5cc6979e6b7aa1f55a64d6b463cc1dcd3c95505a63e48fe
#              Got        9b311c7adb16821d6e45126c56b9bd1a14113f79717b0c2afb1bb52c4475af38

# %%
import os
import cv
import numpy as np
import json
import random
from PIL import Image, ImageDraw, ImageFont
import asyncio

import requests
import base64
import gradio as gr
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 import os
# ----> 2 import cv
#       3 import numpy as np
#       4 import json
#
# ModuleNotFoundError: No module named 'cv'

# %%
pip install opencv-python
# Out:
# Collecting opencv-pythonNote: you may need to restart the kernel to use updated packages.
#
#   Obtaining dependency information for opencv-python from https://files.pythonhosted.org/packages/ec/6c/fab8113424af5049f85717e8e527ca3773299a3c6b02506e66436e19874f/opencv_python-4.10.0.84-cp37-abi3-win_amd64.whl.metadata
#   Using cached opencv_python-4.10.0.84-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\admin\anaconda3\lib\site-packages (from opencv-python) (1.24.3)
# Downloading opencv_python-4.10.0.84-cp37-abi3-win_amd64.whl (38.8 MB)
#    ---------------------------------------- 0.0/38.8 MB ? eta -:--:--
#    ---------------------------------------- 0.1/38.8 MB 1.6 MB/s eta 0:00:25
#    ---------------------------------------- 0.1/38.8 MB 2.1 MB/s eta 0:00:19
#    ---------------------------------------- 0.3/38.8 MB 2.1 MB/s eta 0:00:19
#    ---------------------------------------- 0.4/38.8 MB 2.0 MB/s eta 0:00:20
#     --------------------------------------- 0.6/38.8 MB 2.7 MB/s eta 0:00:15
#     --------------------------------------- 0.8/38.8 MB 2.7 MB/s eta 0:00:15
#    - -------------------------------------- 1.0/38.8 MB 3.0 MB/s eta 0:00:13
#    - -------------------------------------- 1.3/38.8 MB 3.1 MB/s eta 0:00:13
#    - -------------------------------------- 1.4/38.8 MB 3.1 MB/s eta 0:00:12
#    - -------------------------------------- 1.6/38.8 MB 3.3 MB/s eta 0:00:12
#    - -------------------------------------- 1.9/38.8 MB 3.4 MB/s eta 0:00:11
#    -- ------------------------------------- 2.2/38.8 MB 3.7 MB/s eta 0:00:10
#    -- ------------------------------------- 2.5/38.8 MB 3.8 MB/s eta 0:00:10
#    -- ------------------------------------- 2.8/38.8 MB 4.0 MB/s eta 0:00:09
#    --- ------------------------------------ 3.2/38.8 MB 4.1 MB/s eta 0:00:09
#    --- ------------------------------------ 3.6/38.8 MB 4.4 MB/s eta 0:00:09
#    ---- ----------------------------------- 3.9/38.8 MB 4.6 MB/s eta 0:00:08
#    ---- ----------------------------------- 4.4/38.8 MB 4.7 MB/s eta 0:00:08
#    ---- ----------------------------------- 4.8/38.8 MB 4.9 MB/s eta 0:00:07
#    ----- ---------------------------------- 5.2/38.8 MB 4.9 MB/s eta 0:00:07
#    ----- ---------------------------------- 5.6/38.8 MB 5.1 MB/s eta 0:00:07
#    ------ --------------------------------- 6.0/38.8 MB 5.3 MB/s eta 0:00:07
#    ------ --------------------------------- 6.5/38.8 MB 5.4 MB/s eta 0:00:06
#    ------- -------------------------------- 6.9/38.8 MB 5.5 MB/s eta 0:00:06
#    ------- -------------------------------- 7.3/38.8 MB 5.6 MB/s eta 0:00:06
#    ------- -------------------------------- 7.7/38.8 MB 5.7 MB/s eta 0:00:06
#    -------- ------------------------------- 8.0/38.8 MB 5.8 MB/s eta 0:00:06
#    -------- ------------------------------- 8.4/38.8 MB 5.8 MB/s eta 0:00:06
#    --------- ------------------------------ 8.8/38.8 MB 5.8 MB/s eta 0:00:06
#    --------- ------------------------------ 9.3/38.8 MB 5.9 MB/s eta 0:00:06
#    --------- ------------------------------ 9.6/38.8 MB 5.9 MB/s eta 0:00:05
#    ---------- ----------------------------- 9.9/38.8 MB 6.0 MB/s eta 0:00:05
#    ---------- ----------------------------- 10.3/38.8 MB 6.0 MB/s eta 0:00:05
#    ---------- ----------------------------- 10.5/38.8 MB 6.2 MB/s eta 0:00:05
#    ----------- ---------------------------- 10.7/38.8 MB 6.5 MB/s eta 0:00:05
#    ----------- ---------------------------- 11.0/38.8 MB 6.5 MB/s eta 0:00:05
#    ----------- ---------------------------- 11.3/38.8 MB 6.7 MB/s eta 0:00:05
#    ----------- ---------------------------- 11.5/38.8 MB 6.7 MB/s eta 0:00:05
#    ------------ --------------------------- 11.8/38.8 MB 6.8 MB/s eta 0:00:04
#    ------------ --------------------------- 12.1/38.8 MB 6.8 MB/s eta 0:00:04
#    ------------ --------------------------- 12.3/38.8 MB 6.9 MB/s eta 0:00:04
#    ------------- -------------------------- 12.7/38.8 MB 6.9 MB/s eta 0:00:04
#    ------------- -------------------------- 13.1/38.8 MB 7.0 MB/s eta 0:00:04
#    ------------- -------------------------- 13.2/38.8 MB 7.0 MB/s eta 0:00:04
#    -------------- ------------------------- 13.9/38.8 MB 7.1 MB/s eta 0:00:04
#    -------------- ------------------------- 14.2/38.8 MB 7.0 MB/s eta 0:00:04
#    --------------- ------------------------ 14.9/38.8 MB 7.2 MB/s eta 0:00:04
#    --------------- ------------------------ 15.2/38.8 MB 7.3 MB/s eta 0:00:04
#    ---------------- ----------------------- 15.7/38.8 MB 7.3 MB/s eta 0:00:04
#    ---------------- ----------------------- 16.1/38.8 MB 7.4 MB/s eta 0:00:04
#    ---------------- ----------------------- 16.4/38.8 MB 7.4 MB/s eta 0:00:04
#    ----------------- ---------------------- 16.9/38.8 MB 7.4 MB/s eta 0:00:03
#    ----------------- ---------------------- 17.3/38.8 MB 7.4 MB/s eta 0:00:03
#    ------------------ --------------------- 17.5/38.8 MB 7.3 MB/s eta 0:00:03
#    ------------------ --------------------- 17.9/38.8 MB 7.4 MB/s eta 0:00:03
#    ------------------ --------------------- 18.2/38.8 MB 7.3 MB/s eta 0:00:03
#    ------------------- -------------------- 18.5/38.8 MB 7.3 MB/s eta 0:00:03
#    ------------------- -------------------- 18.9/38.8 MB 7.3 MB/s eta 0:00:03
#    ------------------- -------------------- 19.2/38.8 MB 7.2 MB/s eta 0:00:03
#    -------------------- ------------------- 19.7/38.8 MB 7.2 MB/s eta 0:00:03
#    -------------------- ------------------- 19.9/38.8 MB 7.3 MB/s eta 0:00:03
#    -------------------- ------------------- 20.3/38.8 MB 7.1 MB/s eta 0:00:03
#    --------------------- ------------------ 20.7/38.8 MB 7.3 MB/s eta 0:00:03
#    --------------------- ------------------ 21.2/38.8 MB 7.4 MB/s eta 0:00:03
#    ---------------------- ----------------- 21.6/38.8 MB 7.5 MB/s eta 0:00:03
#    ---------------------- ----------------- 21.9/38.8 MB 7.5 MB/s eta 0:00:03
#    ---------------------- ----------------- 22.1/38.8 MB 7.5 MB/s eta 0:00:03
#    ----------------------- ---------------- 22.6/38.8 MB 7.7 MB/s eta 0:00:03
#    ----------------------- ---------------- 22.9/38.8 MB 7.5 MB/s eta 0:00:03
#    ------------------------ --------------- 23.4/38.8 MB 7.7 MB/s eta 0:00:03
#    ------------------------ --------------- 23.8/38.8 MB 7.9 MB/s eta 0:00:02
#    ------------------------ --------------- 24.2/38.8 MB 7.8 MB/s eta 0:00:02
#    ------------------------- -------------- 24.6/38.8 MB 7.8 MB/s eta 0:00:02
#    ------------------------- -------------- 24.9/38.8 MB 7.7 MB/s eta 0:00:02
#    -------------------------- ------------- 25.5/38.8 MB 7.7 MB/s eta 0:00:02
#    -------------------------- ------------- 26.0/38.8 MB 7.6 MB/s eta 0:00:02
#    --------------------------- ------------ 26.6/38.8 MB 7.7 MB/s eta 0:00:02
#    --------------------------- ------------ 27.0/38.8 MB 7.6 MB/s eta 0:00:02
#    ---------------------------- ----------- 27.5/38.8 MB 7.6 MB/s eta 0:00:02
#    ---------------------------- ----------- 27.9/38.8 MB 7.8 MB/s eta 0:00:02
#    ----------------------------- ---------- 28.3/38.8 MB 7.8 MB/s eta 0:00:02
#    ----------------------------- ---------- 28.7/38.8 MB 7.8 MB/s eta 0:00:02
#    ----------------------------- ---------- 29.1/38.8 MB 7.9 MB/s eta 0:00:02
#    ------------------------------ --------- 29.5/38.8 MB 8.1 MB/s eta 0:00:02
#    ------------------------------ --------- 29.6/38.8 MB 8.1 MB/s eta 0:00:02
#    ------------------------------ --------- 30.0/38.8 MB 8.0 MB/s eta 0:00:02
#    ------------------------------- -------- 30.5/38.8 MB 8.1 MB/s eta 0:00:02
#    ------------------------------- -------- 30.8/38.8 MB 8.0 MB/s eta 0:00:02
#    -------------------------------- ------- 31.1/38.8 MB 8.0 MB/s eta 0:00:01
#    -------------------------------- ------- 31.3/38.8 MB 7.8 MB/s eta 0:00:01
#    -------------------------------- ------- 31.7/38.8 MB 7.8 MB/s eta 0:00:01
#    -------------------------------- ------- 32.0/38.8 MB 7.9 MB/s eta 0:00:01
#    --------------------------------- ------ 32.3/38.8 MB 7.9 MB/s eta 0:00:01
#    --------------------------------- ------ 32.7/38.8 MB 8.0 MB/s eta 0:00:01
#    ---------------------------------- ----- 33.1/38.8 MB 8.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 33.4/38.8 MB 7.9 MB/s eta 0:00:01
#    ---------------------------------- ----- 33.8/38.8 MB 8.0 MB/s eta 0:00:01
#    ----------------------------------- ---- 34.0/38.8 MB 7.8 MB/s eta 0:00:01
#    ----------------------------------- ---- 34.4/38.8 MB 7.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 34.6/38.8 MB 7.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 34.9/38.8 MB 7.4 MB/s eta 0:00:01
#    ------------------------------------ --- 35.2/38.8 MB 7.5 MB/s eta 0:00:01
#    ------------------------------------ --- 35.7/38.8 MB 7.4 MB/s eta 0:00:01
#    ------------------------------------- -- 36.3/38.8 MB 7.4 MB/s eta 0:00:01
#    ------------------------------------- -- 36.8/38.8 MB 7.4 MB/s eta 0:00:01
#    -------------------------------------- - 37.1/38.8 MB 7.4 MB/s eta 0:00:01
#    -------------------------------------- - 37.4/38.8 MB 7.3 MB/s eta 0:00:01
#    ---------------------------------------  38.0/38.8 MB 7.3 MB/s eta 0:00:01
#    ---------------------------------------  38.3/38.8 MB 7.3 MB/s eta 0:00:01
#    ---------------------------------------  38.6/38.8 MB 7.3 MB/s eta 0:00:01
#    ---------------------------------------  38.8/38.8 MB 7.2 MB/s eta 0:00:01
#    ---------------------------------------  38.8/38.8 MB 7.2 MB/s eta 0:00:01
#    ---------------------------------------  38.8/38.8 MB 7.2 MB/s eta 0:00:01
#    ---------------------------------------- 38.8/38.8 MB 6.3 MB/s eta 0:00:00
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.10.0.84

# %%
import os
import cv2
import numpy as np
import json
import random
from PIL import Image, ImageDraw, ImageFont
import asyncio

import requests
import base64
import gradio as gr
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 11
#       9 import requests
#      10 import base64
# ---> 11 import gradio as gr
#
# ModuleNotFoundError: No module named 'gradio'

# %%
pip install gradio
# Out:
# Requirement already satisfied: gradio in c:\users\admin\anaconda3\lib\site-packages (4.37.2)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in c:\users\admin\anaconda3\lib\site-packages (from gradio) (22.1.0)
# Requirement already satisfied: altair<6.0,>=4.2.0 in c:\users\admin\anaconda3\lib\site-packages (from gradio) (5.3.0)
# Requirement already satisfied: fastapi in c:\users\admin\anaconda3\lib\site-packages (from gradio) (0.111.0)
# Requirement already satisfied: ffmpy in c:\users\admin\anaconda3\lib\site-packages (from gradio) (0.3.2)
# Requirement already satisfied: gradio-client==1.0.2 in c:\users\admin\anaconda3\lib\site-packages (from gradio) (1.0.2)
# Requirement already satisfied: httpx>=0.24.1 in c:\users\admin\anaconda3\lib\site-packages (from gradio) (0.27.0)
# Requirement already satisfied: huggingface-hub>=0.19.3 in c:\users\admin\anaconda3\lib\site-packages (from gradio) (0.23.4)
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in c:\users\admin\anaconda3\lib\site-packages (from gradio) (6.4.0)
# Requirement already satisfied: jinja2<4.0 in c:\users\admin\anaconda3\lib\site-packages (from gradio) (3.1.2)
# Requirement already satisfied: markupsafe~=2.0 in c:\users\admin\anaconda3\lib\site-packages (from gradio) (2.1.1)
# Requirement already satisfied: matplotlib~=3.0 in c:\users\admin\anaconda3\lib\site-packages (from gradio) (3.7.1)
# Requirement already satisfied: numpy<3.0,>=1.0 in c:\users\admin\anaconda3\lib\site-packages (from gradio) (1.24.3)
# Requirement already satisfied: orjson~=3.0 in c:\users\admin\anaconda3\lib\site-packages (from gradio) (3.10.6)
# Requirement already satisfied: packaging in c:\users\admin\anaconda3\lib\site-packages (from gradio) (23.0)
# Requirement already satisfied: pandas<3.0,>=1.0 in c:\users\admin\anaconda3\lib\site-packages (from gradio) (1.5.3)
# Requirement already satisfied: pillow<11.0,>=8.0 in c:\users\admin\anaconda3\lib\site-packages (from gradio) (9.4.0)
# Requirement already satisfied: pydantic>=2.0 in c:\users\admin\anaconda3\lib\site-packages (from gradio) (2.7.1)
# Requirement already satisfied: pydub in c:\users\admin\anaconda3\lib\site-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.9 in c:\users\admin\anaconda3\lib\site-packages (from gradio) (0.0.9)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in c:\users\admin\anaconda3\lib\site-packages (from gradio) (6.0)
# Requirement already satisfied: ruff>=0.2.2 in c:\users\admin\anaconda3\lib\site-packages (from gradio) (0.5.1)
# Requirement already satisfied: semantic-version~=2.0 in c:\users\admin\anaconda3\lib\site-packages (from gradio) (2.10.0)
# Requirement already satisfied: tomlkit==0.12.0 in c:\users\admin\anaconda3\lib\site-packages (from gradio) (0.12.0)
# Requirement already satisfied: typer<1.0,>=0.12 in c:\users\admin\anaconda3\lib\site-packages (from gradio) (0.12.3)
# Requirement already satisfied: typing-extensions~=4.0 in c:\users\admin\anaconda3\lib\site-packages (from gradio) (4.11.0)
# Requirement already satisfied: urllib3~=2.0 in c:\users\admin\anaconda3\lib\site-packages (from gradio) (2.2.2)
# Requirement already satisfied: uvicorn>=0.14.0 in c:\users\admin\anaconda3\lib\site-packages (from gradio) (0.30.1)
# Requirement already satisfied: fsspec in c:\users\admin\anaconda3\lib\site-packages (from gradio-client==1.0.2->gradio) (2024.6.1)
# Requirement already satisfied: websockets<12.0,>=10.0 in c:\users\admin\anaconda3\lib\site-packages (from gradio-client==1.0.2->gradio) (11.0.3)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\admin\anaconda3\lib\site-packages (from altair<6.0,>=4.2.0->gradio) (4.17.3)
# Requirement already satisfied: toolz in c:\users\admin\anaconda3\lib\site-packages (from altair<6.0,>=4.2.0->gradio) (0.12.0)
# Requirement already satisfied: anyio in c:\users\admin\anaconda3\lib\site-packages (from httpx>=0.24.1->gradio) (3.5.0)
# Requirement already satisfied: certifi in c:\users\admin\anaconda3\lib\site-packages (from httpx>=0.24.1->gradio) (2023.7.22)
# Requirement already satisfied: httpcore==1.* in c:\users\admin\anaconda3\lib\site-packages (from httpx>=0.24.1->gradio) (1.0.5)
# Requirement already satisfied: idna in c:\users\admin\anaconda3\lib\site-packages (from httpx>=0.24.1->gradio) (3.4)
# Requirement already satisfied: sniffio in c:\users\admin\anaconda3\lib\site-packages (from httpx>=0.24.1->gradio) (1.2.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\admin\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.24.1->gradio) (0.14.0)
# Requirement already satisfied: filelock in c:\users\admin\anaconda3\lib\site-packages (from huggingface-hub>=0.19.3->gradio) (3.9.0)
# Requirement already satisfied: requests in c:\users\admin\anaconda3\lib\site-packages (from huggingface-hub>=0.19.3->gradio) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\admin\anaconda3\lib\site-packages (from huggingface-hub>=0.19.3->gradio) (4.65.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib~=3.0->gradio) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib~=3.0->gradio) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib~=3.0->gradio) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib~=3.0->gradio) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib~=3.0->gradio) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib~=3.0->gradio) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\admin\anaconda3\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2022.7)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\admin\anaconda3\lib\site-packages (from pydantic>=2.0->gradio) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.2 in c:\users\admin\anaconda3\lib\site-packages (from pydantic>=2.0->gradio) (2.18.2)
# Requirement already satisfied: click>=8.0.0 in c:\users\admin\anaconda3\lib\site-packages (from typer<1.0,>=0.12->gradio) (8.0.4)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\admin\anaconda3\lib\site-packages (from typer<1.0,>=0.12->gradio) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\admin\anaconda3\lib\site-packages (from typer<1.0,>=0.12->gradio) (13.7.1)
# Requirement already satisfied: starlette<0.38.0,>=0.37.2 in c:\users\admin\anaconda3\lib\site-packages (from fastapi->gradio) (0.37.2)
# Requirement already satisfied: fastapi-cli>=0.0.2 in c:\users\admin\anaconda3\lib\site-packages (from fastapi->gradio) (0.0.4)
# Requirement already satisfied: ujson!=4.0.2,!=4.1.0,!=4.2.0,!=4.3.0,!=5.0.0,!=5.1.0,>=4.0.1 in c:\users\admin\anaconda3\lib\site-packages (from fastapi->gradio) (5.4.0)
# Requirement already satisfied: email_validator>=2.0.0 in c:\users\admin\anaconda3\lib\site-packages (from fastapi->gradio) (2.2.0)
# Requirement already satisfied: colorama in c:\users\admin\anaconda3\lib\site-packages (from click>=8.0.0->typer<1.0,>=0.12->gradio) (0.4.6)
# Requirement already satisfied: dnspython>=2.0.0 in c:\users\admin\anaconda3\lib\site-packages (from email_validator>=2.0.0->fastapi->gradio) (2.6.1)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\admin\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\admin\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (0.18.0)
# Requirement already satisfied: six>=1.5 in c:\users\admin\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib~=3.0->gradio) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\admin\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\admin\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.15.1)
# Requirement already satisfied: httptools>=0.5.0 in c:\users\admin\anaconda3\lib\site-packages (from uvicorn>=0.14.0->gradio) (0.6.1)
# Requirement already satisfied: python-dotenv>=0.13 in c:\users\admin\anaconda3\lib\site-packages (from uvicorn>=0.14.0->gradio) (1.0.1)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\admin\anaconda3\lib\site-packages (from uvicorn>=0.14.0->gradio) (0.22.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\admin\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.19.3->gradio) (2.0.4)
# Requirement already satisfied: mdurl~=0.1 in c:\users\admin\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import cv2
import numpy as np
import json
import random
from PIL import Image, ImageDraw, ImageFont
import asyncio

import requests
import base64
import gradio as gr

# %%
machine_number = 0
model = os.path.join(os.path.dirname(models), "models/eva/Eva_0.png")

MODEL_MAP = {
    "AI Model Rouyan_0": 'models/rouyan_new/Rouyan_0.png',
    "AI Model Rouyan_1": 'models/rouyan_new/Rouyan_1.png',
    "AI Model Rouyan_2": 'models/rouyan_new/Rouyan_2.png',
    "AI Model Eva_0": 'models/eva/Eva_0.png',
    "AI Model Eva_1": 'models/eva/Eva_1.png',
    "AI Model Simon_0": 'models/simon_online/Simon_0.png',
    "AI Model Simon_1": 'models/simon_online/Simon_1.png',
    "AI Model Xuanxuan_0": 'models/xiaoxuan_online/Xuanxuan_0.png',
    "AI Model Xuanxuan_1": 'models/xiaoxuan_online/Xuanxuan_1.png',
    "AI Model Xuanxuan_2": 'models/xiaoxuan_online/Xuanxuan_2.png',
    "AI Model Yaqi_0": 'models/yaqi/Yaqi_0.png',
    "AI Model Yaqi_1": 'models/yaqi/Yaqi_1.png',
    "AI Model Yaqi_2": 'models/yaqi/Yaqi_2.png',
    "AI Model Yaqi_3": 'models/yaqi/Yaqi_3.png',
    "AI Model Yifeng_0": 'models/yifeng_online/Yifeng_0.png',
    "AI Model Yifeng_1": 'models/yifeng_online/Yifeng_1.png',
    "AI Model Yifeng_2": 'models/yifeng_online/Yifeng_2.png',
    "AI Model Yifeng_3": 'models/yifeng_online/Yifeng_3.png',
}

def add_waterprint(img):

    h, w, _ = img.shape
    img = cv2.putText(img, 'Powered by OutfitAnyone', (int(0.3*w), h-20), cv2.FONT_HERSHEY_PLAIN, 2, (128, 128, 128), 2, cv2.LINE_AA)

    return img


def get_tryon_result(model_name, garment1, garment2, seed=1234):

    # model_name = "AI Model " + model_name.split("\\")[-1].split(".")[0] # windows
    model_name = "AI Model " + model_name.split("/")[-1].split(".")[0] # linux
    print(model_name)

    encoded_garment1 = cv2.imencode('.jpg', garment1)[1].tobytes()
    encoded_garment1 = base64.b64encode(encoded_garment1).decode('utf-8')

    if garment2 is not None:
        encoded_garment2 = cv2.imencode('.jpg', garment2)[1].tobytes()
        encoded_garment2 = base64.b64encode(encoded_garment2).decode('utf-8')
    else:
        encoded_garment2 = ''

    url = os.environ['OA_IP_ADDRESS']
    headers = {'Content-Type': 'application/json'}
    seed = random.randint(0, 1222222222)
    data = {
        "garment1": encoded_garment1,
        "garment2": encoded_garment2,
        "model_name": model_name,
        "seed": seed
    }
    response = requests.post(url, headers=headers, data=json.dumps(data))
    print("response code", response.status_code)
    if response.status_code == 200:
        result = response.json()
        result = base64.b64decode(result['images'][0])
        result_np = np.frombuffer(result, np.uint8)
        result_img = cv2.imdecode(result_np, cv2.IMREAD_UNCHANGED)
    else:
        print('server error!')

    
    final_img = add_waterprint(result_img)

    return final_img



with gr.Blocks(css = ".output-image, .input-image, .image-preview {height: 400px !important} ") as demo:
    # gr.Markdown("# Outfit Anyone v0.9")
    gr.HTML(
        """
        <div style="display: flex; justify-content: center; align-items: center; text-align: center;">
        <a href="https://github.com/HumanAIGC/OutfitAnyone" style="margin-right: 20px; text-decoration: none; display: flex; align-items: center;">
        </a>
        <div>
            <h1 >Outfit Anyone: Ultra-high quality virtual try-on for Any Clothing and Any Person</h1>
            <h4 >v0.9</h4>
            <h5 style="margin: 0;">If you like our project, please give us a star  on Github to stay updated with the latest developments.</h5>
            <div style="display: flex; justify-content: center; align-items: center; text-align: center;>
                <a href="https://github.com/HumanAIGC/OutfitAnyone"><img src="https://img.shields.io/badge/Arxiv-0000.00000-red"></a>
                <a href='https://humanaigc.github.io/outfit-anyone/'><img src='https://img.shields.io/badge/Project_Page-OutfitAnyone-green' alt='Project Page'></a>
                <a href='https://github.com/HumanAIGC/OutfitAnyone'><img src='https://img.shields.io/badge/Github-Repo-blue'></a>
            </div>
        </div>
        </div>
        """)
    with gr.Row():
        with gr.Column():
            init_image = gr.Image(sources='clipboard', type="filepath", label="model", value=model)
            example = gr.Examples(inputs=init_image,
                                  examples_per_page=4,
                                  examples=[os.path.join(os.path.dirname(__file__), MODEL_MAP.get('AI Model Rouyan_0')),
                                            os.path.join(os.path.dirname(__file__), MODEL_MAP.get('AI Model Rouyan_2')),
                                            os.path.join(os.path.dirname(__file__), MODEL_MAP.get('AI Model Eva_0')),
                                            os.path.join(os.path.dirname(__file__), MODEL_MAP.get('AI Model Simon_1')),
                                            os.path.join(os.path.dirname(__file__), MODEL_MAP.get('AI Model Eva_1')),
                                            os.path.join(os.path.dirname(__file__), MODEL_MAP.get('AI Model Simon_0')),
                                            os.path.join(os.path.dirname(__file__), MODEL_MAP.get('AI Model Xuanxuan_0')),
                                            os.path.join(os.path.dirname(__file__), MODEL_MAP.get('AI Model Xuanxuan_2')),
                                            os.path.join(os.path.dirname(__file__), MODEL_MAP.get('AI Model Yaqi_1')),
                                            os.path.join(os.path.dirname(__file__), MODEL_MAP.get('AI Model Yifeng_0')),
                                            os.path.join(os.path.dirname(__file__), MODEL_MAP.get('AI Model Yifeng_3')),
                                            os.path.join(os.path.dirname(__file__), MODEL_MAP.get('AI Model Rouyan_1')),
                                            os.path.join(os.path.dirname(__file__), MODEL_MAP.get('AI Model Yifeng_2')),
                                            os.path.join(os.path.dirname(__file__), MODEL_MAP.get('AI Model Yaqi_0')),
                                            ])
        with gr.Column():
            gr.HTML(
                """
                <div style="display: flex; justify-content: center; align-items: center; text-align: center;">
                <div>
                    <h3>Models are fixed and cannot be uploaded or modified; we only support users uploading their own garments.</h3>
                    <h4 style="margin: 0;">For a one-piece dress or coat, you only need to upload the image to the 'top garment' section and leave the 'lower garment' section empty.</h4>
                </div>
                </div>
                """)
            with gr.Row():
                garment_top = gr.Image(sources='upload', type="numpy", label="top garment")
                example_top = gr.Examples(inputs=garment_top,
                                          examples_per_page=5,
                                          examples=[os.path.join(os.path.dirname(__file__), "garments/top222.JPG"),
                                                    os.path.join(os.path.dirname(__file__), "garments/top5.png"),
                                                    os.path.join(os.path.dirname(__file__), "garments/top333.png"),
                                                    os.path.join(os.path.dirname(__file__), "garments/dress1.png"),
                                                    os.path.join(os.path.dirname(__file__), "garments/dress2.png"),
                                                            ])
                garment_down = gr.Image(sources='upload', type="numpy", label="lower garment")
                example_down = gr.Examples(inputs=garment_down,
                                           examples_per_page=5,
                                           examples=[os.path.join(os.path.dirname(__file__), "garments/bottom1.png"),
                                                     os.path.join(os.path.dirname(__file__), "garments/bottom2.PNG"),
                                                     os.path.join(os.path.dirname(__file__), "garments/bottom3.JPG"),
                                                     os.path.join(os.path.dirname(__file__), "garments/bottom4.PNG"),
                                                     os.path.join(os.path.dirname(__file__), "garments/bottom5.png"),
                                                            ])

            run_button = gr.Button(value="Run")
        with gr.Column():
            gallery = gr.Image()

            run_button.click(fn=get_tryon_result, 
                             inputs=[
                                    init_image,
                                    garment_top,
                                    garment_down,
                                    ], 
                             outputs=[gallery],
                             concurrency_limit=2)
        

    # Examples
    gr.Markdown("## Examples")
    with gr.Row():
        reference_image1  = gr.Image(label="model", scale=1, value="examples/basemodel.png")
        reference_image2  = gr.Image(label="garment", scale=1, value="examples/garment1.jpg")
        reference_image3  = gr.Image(label="result", scale=1, value="examples/result1.png")
    gr.Examples(
        examples=[
            ["examples/basemodel.png", "examples/garment1.png", "examples/result1.png"],
            ["examples/basemodel.png", "examples/garment2.png", "examples/result2.png"],
            ["examples/basemodel.png", "examples/garment3.png", "examples/result3.png"],
        ],
        inputs=[reference_image1, reference_image2, reference_image3],
        label=None,
    )

if __name__ == "__main__":
    ip = requests.get('http://ifconfig.me/ip', timeout=1).text.strip()
    print("ip address alibaba", ip)
    demo.queue(max_size=10)
    demo.launch()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 machine_number = 0
# ----> 2 model = os.path.join(os.path.dirname(models), "models/eva/Eva_0.png")
#       4 MODEL_MAP = {
#       5     "AI Model Rouyan_0": 'models/rouyan_new/Rouyan_0.png',
#       6     "AI Model Rouyan_1": 'models/rouyan_new/Rouyan_1.png',
#    (...)
#      22     "AI Model Yifeng_3": 'models/yifeng_online/Yifeng_3.png',
#      23 }
#      25 def add_waterprint(img):
#
# NameError: name 'models' is not defined

# %%
machine_number = 0
model = os.path.join(os.getcwd(), "models/eva/Eva_0.png")

MODEL_MAP = {
    "AI Model Rouyan_0": 'models/rouyan_new/Rouyan_0.png',
    "AI Model Rouyan_1": 'models/rouyan_new/Rouyan_1.png',
    "AI Model Rouyan_2": 'models/rouyan_new/Rouyan_2.png',
    "AI Model Eva_0": 'models/eva/Eva_0.png',
    "AI Model Eva_1": 'models/eva/Eva_1.png',
    "AI Model Simon_0": 'models/simon_online/Simon_0.png',
    "AI Model Simon_1": 'models/simon_online/Simon_1.png',
    "AI Model Xuanxuan_0": 'models/xiaoxuan_online/Xuanxuan_0.png',
    "AI Model Xuanxuan_1": 'models/xiaoxuan_online/Xuanxuan_1.png',
    "AI Model Xuanxuan_2": 'models/xiaoxuan_online/Xuanxuan_2.png',
    "AI Model Yaqi_0": 'models/yaqi/Yaqi_0.png',
    "AI Model Yaqi_1": 'models/yaqi/Yaqi_1.png',
    "AI Model Yaqi_2": 'models/yaqi/Yaqi_2.png',
    "AI Model Yaqi_3": 'models/yaqi/Yaqi_3.png',
    "AI Model Yifeng_0": 'models/yifeng_online/Yifeng_0.png',
    "AI Model Yifeng_1": 'models/yifeng_online/Yifeng_1.png',
    "AI Model Yifeng_2": 'models/yifeng_online/Yifeng_2.png',
    "AI Model Yifeng_3": 'models/yifeng_online/Yifeng_3.png',
}

def add_waterprint(img):
    h, w, _ = img.shape
    img = cv2.putText(img, 'Powered by OutfitAnyone', (int(0.3 * w), h - 20), cv2.FONT_HERSHEY_PLAIN, 2, (128, 128, 128), 2, cv2.LINE_AA)
    return img

def get_tryon_result(model_name, garment1, garment2, seed=1234):
    model_name = "AI Model " + model_name.split("/")[-1].split(".")[0] # linux
    print(model_name)

    encoded_garment1 = cv2.imencode('.jpg', garment1)[1].tobytes()
    encoded_garment1 = base64.b64encode(encoded_garment1).decode('utf-8')

    if garment2 is not None:
        encoded_garment2 = cv2.imencode('.jpg', garment2)[1].tobytes()
        encoded_garment2 = base64.b64encode(encoded_garment2).decode('utf-8')
    else:
        encoded_garment2 = ''

    url = os.environ['OA_IP_ADDRESS']
    headers = {'Content-Type': 'application/json'}
    seed = random.randint(0, 1222222222)
    data = {
        "garment1": encoded_garment1,
        "garment2": encoded_garment2,
        "model_name": model_name,
        "seed": seed
    }
    response = requests.post(url, headers=headers, data=json.dumps(data))
    print("response code", response.status_code)
    if response.status_code == 200:
        result = response.json()
        result = base64.b64decode(result['images'][0])
        result_np = np.frombuffer(result, np.uint8)
        result_img = cv2.imdecode(result_np, cv2.IMREAD_UNCHANGED)
    else:
        print('server error!')

    final_img = add_waterprint(result_img)
    return final_img

with gr.Blocks(css=".output-image, .input-image, .image-preview {height: 400px !important}") as demo:
    gr.HTML(
        """
        <div style="display: flex; justify-content: center; align-items: center; text-align: center;">
        <a href="https://github.com/HumanAIGC/OutfitAnyone" style="margin-right: 20px; text-decoration: none; display: flex; align-items: center;">
        </a>
        <div>
            <h1>Outfit Anyone: Ultra-high quality virtual try-on for Any Clothing and Any Person</h1>
            <h4>v0.9</h4>
            <h5 style="margin: 0;">If you like our project, please give us a star on Github to stay updated with the latest developments.</h5>
            <div style="display: flex; justify-content: center; align-items: center; text-align: center;">
                <a href="https://github.com/HumanAIGC/OutfitAnyone"><img src="https://img.shields.io/badge/Arxiv-0000.00000-red"></a>
                <a href='https://humanaigc.github.io/outfit-anyone/'><img src='https://img.shields.io/badge/Project_Page-OutfitAnyone-green' alt='Project Page'></a>
                <a href='https://github.com/HumanAIGC/OutfitAnyone'><img src='https://img.shields.io/badge/Github-Repo-blue'></a>
            </div>
        </div>
        </div>
        """)
    with gr.Row():
        with gr.Column():
            init_image = gr.Image(sources='clipboard', type="filepath", label="model", value=model)
            example = gr.Examples(inputs=init_image,
                                  examples_per_page=4,
                                  examples=[os.getcwd(), MODEL_MAP.get('AI Model Rouyan_0'),
                                            os.getcwd(), MODEL_MAP.get('AI Model Rouyan_2'),
                                            os.getcwd(), MODEL_MAP.get('AI Model Eva_0'),
                                            os.getcwd(), MODEL_MAP.get('AI Model Simon_1'),
                                            os.getcwd(), MODEL_MAP.get('AI Model Eva_1'),
                                            os.getcwd(), MODEL_MAP.get('AI Model Simon_0'),
                                            os.getcwd(), MODEL_MAP.get('AI Model Xuanxuan_0'),
                                            os.getcwd(), MODEL_MAP.get('AI Model Xuanxuan_2'),
                                            os.getcwd(), MODEL_MAP.get('AI Model Yaqi_1'),
                                            os.getcwd(), MODEL_MAP.get('AI Model Yifeng_0'),
                                            os.getcwd(), MODEL_MAP.get('AI Model Yifeng_3'),
                                            os.getcwd(), MODEL_MAP.get('AI Model Rouyan_1'),
                                            os.getcwd(), MODEL_MAP.get('AI Model Yifeng_2'),
                                            os.getcwd(), MODEL_MAP.get('AI Model Yaqi_0'),
                                            ])
        with gr.Column():
            gr.HTML(
                """
                <div style="display: flex; justify-content: center; align-items: center; text-align: center;">
                <div>
                    <h3>Models are fixed and cannot be uploaded or modified; we only support users uploading their own garments.</h3>
                    <h4 style="margin: 0;">For a one-piece dress or coat, you only need to upload the image to the 'top garment' section and leave the 'lower garment' section empty.</h4>
                </div>
                </div>
                """)
            with gr.Row():
                garment_top = gr.Image(sources='upload', type="numpy", label="top garment")
                example_top = gr.Examples(inputs=garment_top,
                                          examples_per_page=5,
                                          examples=[os.getcwd(), "garments/top222.JPG",
                                                    os.getcwd(), "garments/top5.png",
                                                    os.getcwd(), "garments/top333.png",
                                                    os.getcwd(), "garments/dress1.png",
                                                    os.getcwd(), "garments/dress2.png",
                                                            ])
                garment_down = gr.Image(sources='upload', type="numpy", label="lower garment")
                example_down = gr.Examples(inputs=garment_down,
                                           examples_per_page=5,
                                           examples=[os.getcwd(), "garments/bottom1.png",
                                                     os.getcwd(), "garments/bottom2.PNG",
                                                     os.getcwd(), "garments/bottom3.JPG",
                                                     os.getcwd(), "garments/bottom4.PNG",
                                                     os.getcwd(), "garments/bottom5.png",
                                                            ])

            run_button = gr.Button(value="Run")
        with gr.Column():
            gallery = gr.Image()

            run_button.click(fn=get_tryon_result, 
                             inputs=[
                                    init_image,
                                    garment_top,
                                    garment_down,
                                    ], 
                             outputs=[gallery],
                             concurrency_limit=2)

    gr.Markdown("## Examples")
    with gr.Row():
        reference_image1 = gr.Image(label="model", scale=1, value="examples/basemodel.png")
        reference_image2 = gr.Image(label="garment", scale=1, value="examples/garment1.jpg")
        reference_image3 = gr.Image(label="result", scale=1, value="examples/result1.png")
    gr.Examples(
        examples=[
            ["examples/basemodel.png", "examples/garment1.png", "examples/result1.png"],
            ["examples/basemodel.png", "examples/garment2.png", "examples/result2.png"],
            ["examples/basemodel.png", "examples/garment3.png", "examples/result3.png"],
        ],
        inputs=[reference_image1, reference_image2, reference_image3],
        label=None,
    )

if __name__ == "__main__":
    ip = requests.get('http://ifconfig.me/ip', timeout=1).text.strip()
    print("ip address alibaba", ip)
    demo.queue(max_size=10)
    demo.launch()
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[10], line 86
#      84 with gr.Column():
#      85     init_image = gr.Image(sources='clipboard', type="filepath", label="model", value=model)
# ---> 86     example = gr.Examples(inputs=init_image,
#      87                           examples_per_page=4,
#      88                           examples=[os.getcwd(), MODEL_MAP.get('AI Model Rouyan_0'),
#      89                                     os.getcwd(), MODEL_MAP.get('AI Model Rouyan_2'),
#      90                                     os.getcwd(), MODEL_MAP.get('AI Model Eva_0'),
#      91                                     os.getcwd(), MODEL_MAP.get('AI Model Simon_1'),
#      92                                     os.getcwd(), MODEL_MAP.get('AI Model Eva_1'),
#      93                                     os.getcwd(), MODEL_MAP.get('AI Model Simon_0'),
#      94                                     os.getcwd(), MODEL_MAP.get('AI Model Xuanxuan_0'),
#      95                                     os.getcwd(), MODEL_MAP.get('AI Model Xuanxuan_2'),
#      96                                     os.getcwd(), MODEL_MAP.get('AI Model Yaqi_1'),
#      97                                     os.getcwd(), MODEL_MAP.get('AI Model Yifeng_0'),
#      98                                     os.getcwd(), MODEL_MAP.get('AI Model Yifeng_3'),
#      99                                     os.getcwd(), MODEL_MAP.get('AI Model Rouyan_1'),
#     100                                     os.getcwd(), MODEL_MAP.get('AI Model Yifeng_2'),
#     101                                     os.getcwd(), MODEL_MAP.get('AI Model Yaqi_0'),
#     102                                     ])
#     103 with gr.Column():
#     104     gr.HTML(
#     105         """
#     106         <div style="display: flex; justify-content: center; align-items: center; text-align: center;">
#    (...)
#     111         </div>
#     112         """)
#
# File ~\anaconda3\Lib\site-packages\gradio\helpers.py:56, in create_examples(examples, inputs, outputs, fn, cache_examples, examples_per_page, _api_mode, label, elem_id, run_on_click, preprocess, postprocess, api_name, batch, _defer_caching)
#      38 def create_examples(
#      39     examples: list[Any] | list[list[Any]] | str,
#      40     inputs: Component | list[Component],
#    (...)
#      53     _defer_caching: bool = False,
#      54 ):
#      55     """Top-level synchronous function that creates Examples. Provided for backwards compatibility, i.e. so that gr.Examples(...) can be used to create the Examples component."""
# ---> 56     examples_obj = Examples(
#      57         examples=examples,
#      58         inputs=inputs,
#      59         outputs=outputs,
#      60         fn=fn,
#      61         cache_examples=cache_examples,
#      62         examples_per_page=examples_per_page,
#      63         _api_mode=_api_mode,
#      64         label=label,
#      65         elem_id=elem_id,
#      66         run_on_click=run_on_click,
#      67         preprocess=preprocess,
#      68         postprocess=postprocess,
#      69         api_name=api_name,
#      70         batch=batch,
#      71         _defer_caching=_defer_caching,
#      72         _initiated_directly=False,
#      73     )
#      74     examples_obj.create()
#      75     return examples_obj
#
# File ~\anaconda3\Lib\site-packages\gradio\helpers.py:245, in Examples.__init__(self, examples, inputs, outputs, fn, cache_examples, examples_per_page, _api_mode, label, elem_id, run_on_click, preprocess, postprocess, api_name, batch, _defer_caching, _initiated_directly)
#     243     if isinstance(prediction_value, (GradioRootModel, GradioModel)):
#     244         prediction_value = prediction_value.model_dump()
# --> 245     prediction_value = processing_utils.move_files_to_cache(
#     246         prediction_value,
#     247         component,
#     248         postprocess=True,
#     249     )
#     250     sub.append(prediction_value)
#     251 self.processed_examples.append(sub)
#
# File ~\anaconda3\Lib\site-packages\gradio\processing_utils.py:416, in move_files_to_cache(data, block, postprocess, check_in_upload_folder, keep_in_cache)
#     413 if isinstance(data, (GradioRootModel, GradioModel)):
#     414     data = data.model_dump()
# --> 416 return client_utils.traverse(data, _move_to_cache, client_utils.is_file_obj)
#
# File ~\anaconda3\Lib\site-packages\gradio_client\utils.py:975, in traverse(json_obj, func, is_root)
#     971 """
#     972 Traverse a JSON object and apply a function to each element that satisfies the is_root condition.
#     973 """
#     974 if is_root(json_obj):
# --> 975     return func(json_obj)
#     976 elif isinstance(json_obj, dict):
#     977     new_obj = {}
#
# File ~\anaconda3\Lib\site-packages\gradio\processing_utils.py:392, in move_files_to_cache.<locals>._move_to_cache(d)
#     388         raise ValueError(
#     389             f"File {path} is not in the upload folder and cannot be accessed."
#     390         )
#     391 if not payload.is_stream:
# --> 392     temp_file_path = block.move_resource_to_block_cache(payload.path)
#     393     if temp_file_path is None:
#     394         raise ValueError("Did not determine a file path for the resource.")
#
# File ~\anaconda3\Lib\site-packages\gradio\blocks.py:334, in Block.move_resource_to_block_cache(self, url_or_file_path)
#     332 if not utils.is_in_or_equal(url_or_file_path, self.GRADIO_CACHE):
#     333     try:
# --> 334         temp_file_path = processing_utils.save_file_to_cache(
#     335             url_or_file_path, cache_dir=self.GRADIO_CACHE
#     336         )
#     337     except FileNotFoundError:
#     338         # This can happen if when using gr.load() and the file is on a remote Space
#     339         # but the file is not the `value` of the component. For example, if the file
#     340         # is the `avatar_image` of the `Chatbot` component. In this case, we skip
#     341         # copying the file to the cache and just use the remote file path.
#     342         return url_or_file_path
#
# File ~\anaconda3\Lib\site-packages\gradio\processing_utils.py:250, in save_file_to_cache(file_path, cache_dir)
#     247 def save_file_to_cache(file_path: str | Path, cache_dir: str) -> str:
#     248     """Returns a temporary file path for a copy of the given file path if it does
#     249     not already exist. Otherwise returns the path to the existing temp file."""
# --> 250     temp_dir = hash_file(file_path)
#     251     temp_dir = Path(cache_dir) / temp_dir
#     252     temp_dir.mkdir(exist_ok=True, parents=True)
#
# File ~\anaconda3\Lib\site-packages\gradio\processing_utils.py:182, in hash_file(file_path, chunk_num_blocks)
#     180 def hash_file(file_path: str | Path, chunk_num_blocks: int = 128) -> str:
#     181     sha1 = hashlib.sha1()
# --> 182     with open(file_path, "rb") as f:
#     183         for chunk in iter(lambda: f.read(chunk_num_blocks * sha1.block_size), b""):
#     184             sha1.update(chunk)
#
# PermissionError: [Errno 13] Permission denied: 'C:\\Users\\Admin\\Desktop\\pranjal\\Myntra\\OutfitAnyone'

# %%
import os
import cv2
import numpy as np
import json
import random
from PIL import Image, ImageDraw, ImageFont
import asyncio

import requests
import base64
import gradio as gr

machine_number = 0
model = os.path.join(os.getcwd(), "models/eva/Eva_0.png")

MODEL_MAP = {
    "AI Model Rouyan_0": 'models/rouyan_new/Rouyan_0.png',
    "AI Model Rouyan_1": 'models/rouyan_new/Rouyan_1.png',
    "AI Model Rouyan_2": 'models/rouyan_new/Rouyan_2.png',
    "AI Model Eva_0": 'models/eva/Eva_0.png',
    "AI Model Eva_1": 'models/eva/Eva_1.png',
    "AI Model Simon_0": 'models/simon_online/Simon_0.png',
    "AI Model Simon_1": 'models/simon_online/Simon_1.png',
    "AI Model Xuanxuan_0": 'models/xiaoxuan_online/Xuanxuan_0.png',
    "AI Model Xuanxuan_1": 'models/xiaoxuan_online/Xuanxuan_1.png',
    "AI Model Xuanxuan_2": 'models/xiaoxuan_online/Xuanxuan_2.png',
    "AI Model Yaqi_0": 'models/yaqi/Yaqi_0.png',
    "AI Model Yaqi_1": 'models/yaqi/Yaqi_1.png',
    "AI Model Yaqi_2": 'models/yaqi/Yaqi_2.png',
    "AI Model Yaqi_3": 'models/yaqi/Yaqi_3.png',
    "AI Model Yifeng_0": 'models/yifeng_online/Yifeng_0.png',
    "AI Model Yifeng_1": 'models/yifeng_online/Yifeng_1.png',
    "AI Model Yifeng_2": 'models/yifeng_online/Yifeng_2.png',
    "AI Model Yifeng_3": 'models/yifeng_online/Yifeng_3.png',
}

def add_waterprint(img):
    h, w, _ = img.shape
    img = cv2.putText(img, 'Powered by OutfitAnyone', (int(0.3 * w), h - 20), cv2.FONT_HERSHEY_PLAIN, 2, (128, 128, 128), 2, cv2.LINE_AA)
    return img

def get_tryon_result(model_name, garment1, garment2, seed=1234):
    model_name = "AI Model " + model_name.split("/")[-1].split(".")[0]  # linux
    print(model_name)

    encoded_garment1 = cv2.imencode('.jpg', garment1)[1].tobytes()
    encoded_garment1 = base64.b64encode(encoded_garment1).decode('utf-8')

    if garment2 is not None:
        encoded_garment2 = cv2.imencode('.jpg', garment2)[1].tobytes()
        encoded_garment2 = base64.b64encode(encoded_garment2).decode('utf-8')
    else:
        encoded_garment2 = ''

    url = os.environ['OA_IP_ADDRESS']
    headers = {'Content-Type': 'application/json'}
    seed = random.randint(0, 1222222222)
    data = {
        "garment1": encoded_garment1,
        "garment2": encoded_garment2,
        "model_name": model_name,
        "seed": seed
    }
    response = requests.post(url, headers=headers, data=json.dumps(data))
    print("response code", response.status_code)
    if response.status_code == 200:
        result = response.json()
        result = base64.b64decode(result['images'][0])
        result_np = np.frombuffer(result, np.uint8)
        result_img = cv2.imdecode(result_np, cv2.IMREAD_UNCHANGED)
    else:
        print('server error!')
        return None

    final_img = add_waterprint(result_img)
    return final_img

with gr.Blocks(css=".output-image, .input-image, .image-preview {height: 400px !important}") as demo:
    gr.HTML(
        """
        <div style="display: flex; justify-content: center; align-items: center; text-align: center;">
        <div>
            <h1>Outfit Anyone: Ultra-high quality virtual try-on for Any Clothing and Any Person</h1>
            <h4>v0.9</h4>
            <h5 style="margin: 0;">If you like our project, please give us a star on Github to stay updated with the latest developments.</h5>
            <div style="display: flex; justify-content: center; align-items: center; text-align: center;">
                <a href="https://github.com/HumanAIGC/OutfitAnyone"><img src="https://img.shields.io/badge/Arxiv-0000.00000-red"></a>
                <a href='https://humanaigc.github.io/outfit-anyone/'><img src='https://img.shields.io/badge/Project_Page-OutfitAnyone-green' alt='Project Page'></a>
                <a href='https://github.com/HumanAIGC/OutfitAnyone'><img src='https://img.shields.io/badge/Github-Repo-blue'></a>
            </div>
        </div>
        </div>
        """)
    with gr.Row():
        with gr.Column():
            init_image = gr.Image(sources='clipboard', type="filepath", label="model", value=model)
            example = gr.Examples(inputs=init_image,
                                  examples_per_page=4,
                                  examples=[MODEL_MAP.get('AI Model Rouyan_0'),
                                            MODEL_MAP.get('AI Model Rouyan_2'),
                                            MODEL_MAP.get('AI Model Eva_0'),
                                            MODEL_MAP.get('AI Model Simon_1'),
                                            MODEL_MAP.get('AI Model Eva_1'),
                                            MODEL_MAP.get('AI Model Simon_0'),
                                            MODEL_MAP.get('AI Model Xuanxuan_0'),
                                            MODEL_MAP.get('AI Model Xuanxuan_2'),
                                            MODEL_MAP.get('AI Model Yaqi_1'),
                                            MODEL_MAP.get('AI Model Yifeng_0'),
                                            MODEL_MAP.get('AI Model Yifeng_3'),
                                            MODEL_MAP.get('AI Model Rouyan_1'),
                                            MODEL_MAP.get('AI Model Yifeng_2'),
                                            MODEL_MAP.get('AI Model Yaqi_0')])
        with gr.Column():
            gr.HTML(
                """
                <div style="display: flex; justify-content: center; align-items: center; text-align: center;">
                <div>
                    <h3>Models are fixed and cannot be uploaded or modified; we only support users uploading their own garments.</h3>
                    <h4 style="margin: 0;">For a one-piece dress or coat, you only need to upload the image to the 'top garment' section and leave the 'lower garment' section empty.</h4>
                </div>
                </div>
                """)
            with gr.Row():
                garment_top = gr.Image(sources='upload', type="numpy", label="top garment")
                example_top = gr.Examples(inputs=garment_top,
                                          examples_per_page=5,
                                          examples=["garments/top222.JPG",
                                                    "garments/top5.png",
                                                    "garments/top333.png",
                                                    "garments/dress1.png",
                                                    "garments/dress2.png"])
                garment_down = gr.Image(sources='upload', type="numpy", label="lower garment")
                example_down = gr.Examples(inputs=garment_down,
                                           examples_per_page=5,
                                           examples=["garments/bottom1.png",
                                                     "garments/bottom2.PNG",
                                                     "garments/bottom3.JPG",
                                                     "garments/bottom4.PNG",
                                                     "garments/bottom5.png"])

            run_button = gr.Button(value="Run")
        with gr.Column():
            gallery = gr.Image()

            run_button.click(fn=get_tryon_result,
                             inputs=[
                                 init_image,
                                 garment_top,
                                 garment_down,
                             ],
                             outputs=[gallery],
                             concurrency_limit=2)

    gr.Markdown("## Examples")
    with gr.Row():
        reference_image1 = gr.Image(label="model", scale=1, value="examples/basemodel.png")
        reference_image2 = gr.Image(label="garment", scale=1, value="examples/garment1.jpg")
        reference_image3 = gr.Image(label="result", scale=1, value="examples/result1.png")
    gr.Examples(
        examples=[
            ["examples/basemodel.png", "examples/garment1.png", "examples/result1.png"],
            ["examples/basemodel.png", "examples/garment2.png", "examples/result2.png"],
            ["examples/basemodel.png", "examples/garment3.png", "examples/result3.png"],
        ],
        inputs=[reference_image1, reference_image2, reference_image3],
        outputs=[gallery],
    )

demo.launch()
# Out:
# Running on local URL:  http://127.0.0.1:7860
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# AI Model C:\Users\Admin\AppData\Local\Temp\gradio\28dbd2deba1e160bfadffbc3675ba4dcac20ca58\Eva_0
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\gradio\queueing.py", line 541, in process_events
#     response = await route_utils.call_process_api(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\gradio\route_utils.py", line 276, in call_process_api
#     output = await app.get_blocks().process_api(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\gradio\blocks.py", line 1928, in process_api
#     result = await self.call_function(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\gradio\blocks.py", line 1514, in call_function
#     prediction = await anyio.to_thread.run_sync(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\anyio\to_thread.py", line 28, in run_sync
#     return await get_asynclib().run_sync_in_worker_thread(func, *args, cancellable=cancellable,
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\anyio\_backends\_asyncio.py", line 818, in run_sync_in_worker_thread
#     return await future
#            ^^^^^^^^^^^^
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\anyio\_backends\_asyncio.py", line 754, in run
#     result = context.run(func, *args)
#              ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\gradio\utils.py", line 833, in wrapper
#     response = f(*args, **kwargs)
#                ^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_1228\326808876.py", line 55, in get_tryon_result
#     url = os.environ['OA_IP_ADDRESS']
#           ~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "<frozen os>", line 679, in __getitem__
# KeyError: 'OA_IP_ADDRESS'
